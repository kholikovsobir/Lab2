# %%
import random
import timeit
import numpy as np
import matplotlib.pyplot as plt

def stoogesort(arr, l, h): 
    if l >= h: 
        return
  
    # Если первый элемент больше последнего, поменять их местами 
    if arr[l] > arr[h]: 
        arr[l], arr[h] = arr[h], arr[l] 
  
    # Если в списке 2 элемента, то сортировка завершена 
    if h - l + 1 > 2: 
        t = (int)((h - l + 1) / 3) 
        # Рекурсивно сортировать первые 2/3 элемента 
        stoogesort(arr, l, (h - t)) 
        # Рекурсивно сортировать последние 2/3 элемента 
        stoogesort(arr, l + t, (h)) 
        # Рекурсивно сортировать первые 2/3 элемента еще раз,
        # чтобы убедиться, что они находятся в правильном порядке 
        stoogesort(arr, l, (h - t)) 

def generate_random_sequence(length):
    sequence = list(range(length))
    random.shuffle(sequence)
    return sequence

def measure_sorting_time(sort_func, sequence):
    l, h = 0, len(sequence) - 1
    return timeit.timeit(lambda: sort_func(sequence, l, h), number=1)

def perform_measurements(sort_func):
    sizes = list(range(1000, 11000, 1000))
    time_data = []

    for size in sizes:
        measurements = []
        for _ in range(10):
            sequence = generate_random_sequence(size)
            measurements.append(measure_sorting_time(sort_func, sequence))
        time_data.append(measurements)

    return sizes, np.array(time_data)

def plot_graph(lengths, mean_times):
    plt.plot(lengths, mean_times, marker='o')
    plt.xlabel('Длина последовательности')
    plt.ylabel('Время выполнения (сек)')
    plt.title('Время выполнения блуждающей сортировки (stooge sort)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

lengths, time_data = perform_measurements(stoogesort)
mean_times = np.mean(time_data, axis=1)
plot_graph(lengths, mean_times)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 56
#      53     plt.tight_layout()
#      54     plt.show()
# ---> 56 lengths, time_data = perform_measurements(stoogesort)
#      57 mean_times = np.mean(time_data, axis=1)
#      58 plot_graph(lengths, mean_times)
#
# Cell In[2], line 42, in perform_measurements(sort_func)
#      40     for _ in range(10):
#      41         sequence = generate_random_sequence(size)
# ---> 42         measurements.append(measure_sorting_time(sort_func, sequence))
#      43     time_data.append(measurements)
#      45 return sizes, np.array(time_data)
#
# Cell In[2], line 32, in measure_sorting_time(sort_func, sequence)
#      30 def measure_sorting_time(sort_func, sequence):
#      31     l, h = 0, len(sequence) - 1
# ---> 32     return timeit.timeit(lambda: sort_func(sequence, l, h), number=1)
#
# File c:\Users\sobir\AppData\Local\Programs\Python\Python312\Lib\timeit.py:237, in timeit(stmt, setup, timer, number, globals)
#     234 def timeit(stmt="pass", setup="pass", timer=default_timer,
#     235            number=default_number, globals=None):
#     236     """Convenience function to create Timer object and call timeit method."""
# --> 237     return Timer(stmt, setup, timer, globals).timeit(number)
#
# File c:\Users\sobir\AppData\Local\Programs\Python\Python312\Lib\timeit.py:180, in Timer.timeit(self, number)
#     178 gc.disable()
#     179 try:
# --> 180     timing = self.inner(it, self.timer)
#     181 finally:
#     182     if gcold:
#
# File <timeit-src>:6, in inner(_it, _timer, _stmt)
#
# Cell In[2], line 32, in measure_sorting_time.<locals>.<lambda>()
#      30 def measure_sorting_time(sort_func, sequence):
#      31     l, h = 0, len(sequence) - 1
# ---> 32     return timeit.timeit(lambda: sort_func(sequence, l, h), number=1)
#
# Cell In[2], line 23, in stoogesort(arr, l, h)
#      20 stoogesort(arr, l + t, (h))
#      21 # Рекурсивно сортировать первые 2/3 элемента еще раз,
#      22 # чтобы убедиться, что они находятся в правильном порядке
# ---> 23 stoogesort(arr, l, (h - t))
#
# Cell In[2], line 20, in stoogesort(arr, l, h)
#      18 stoogesort(arr, l, (h - t))
#      19 # Рекурсивно сортировать последние 2/3 элемента
# ---> 20 stoogesort(arr, l + t, (h))
#      21 # Рекурсивно сортировать первые 2/3 элемента еще раз,
#      22 # чтобы убедиться, что они находятся в правильном порядке
#      23 stoogesort(arr, l, (h - t))
#
# Cell In[2], line 18, in stoogesort(arr, l, h)
#      16 t = (int)((h - l + 1) / 3)
#      17 # Рекурсивно сортировать первые 2/3 элемента
# ---> 18 stoogesort(arr, l, (h - t))
#      19 # Рекурсивно сортировать последние 2/3 элемента
#      20 stoogesort(arr, l + t, (h))
#
# Cell In[2], line 20, in stoogesort(arr, l, h)
#      18 stoogesort(arr, l, (h - t))
#      19 # Рекурсивно сортировать последние 2/3 элемента
# ---> 20 stoogesort(arr, l + t, (h))
#      21 # Рекурсивно сортировать первые 2/3 элемента еще раз,
#      22 # чтобы убедиться, что они находятся в правильном порядке
#      23 stoogesort(arr, l, (h - t))
#
# Cell In[2], line 18, in stoogesort(arr, l, h)
#      16 t = (int)((h - l + 1) / 3)
#      17 # Рекурсивно сортировать первые 2/3 элемента
# ---> 18 stoogesort(arr, l, (h - t))
#      19 # Рекурсивно сортировать последние 2/3 элемента
#      20 stoogesort(arr, l + t, (h))
#
#     [... skipping similar frames: stoogesort at line 20 (1 times)]
#
# Cell In[2], line 23, in stoogesort(arr, l, h)
#      20 stoogesort(arr, l + t, (h))
#      21 # Рекурсивно сортировать первые 2/3 элемента еще раз,
#      22 # чтобы убедиться, что они находятся в правильном порядке
# ---> 23 stoogesort(arr, l, (h - t))
#
#     [... skipping similar frames: stoogesort at line 18 (3 times), stoogesort at line 20 (2 times), stoogesort at line 23 (2 times)]
#
# Cell In[2], line 23, in stoogesort(arr, l, h)
#      20 stoogesort(arr, l + t, (h))
#      21 # Рекурсивно сортировать первые 2/3 элемента еще раз,
#      22 # чтобы убедиться, что они находятся в правильном порядке
# ---> 23 stoogesort(arr, l, (h - t))
#
# Cell In[2], line 18, in stoogesort(arr, l, h)
#      16 t = (int)((h - l + 1) / 3)
#      17 # Рекурсивно сортировать первые 2/3 элемента
# ---> 18 stoogesort(arr, l, (h - t))
#      19 # Рекурсивно сортировать последние 2/3 элемента
#      20 stoogesort(arr, l + t, (h))
#
# Cell In[2], line 20, in stoogesort(arr, l, h)
#      18 stoogesort(arr, l, (h - t))
#      19 # Рекурсивно сортировать последние 2/3 элемента
# ---> 20 stoogesort(arr, l + t, (h))
#      21 # Рекурсивно сортировать первые 2/3 элемента еще раз,
#      22 # чтобы убедиться, что они находятся в правильном порядке
#      23 stoogesort(arr, l, (h - t))
#
# Cell In[2], line 16, in stoogesort(arr, l, h)
#      14 # Если в списке 2 элемента, то сортировка завершена
#      15 if h - l + 1 > 2:
# ---> 16     t = (int)((h - l + 1) / 3)
#      17     # Рекурсивно сортировать первые 2/3 элемента
#      18     stoogesort(arr, l, (h - t))
#
# KeyboardInterrupt:
